# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%B5%9C%EC%8B%A0%EC%98%81%ED%99%94')

response.encoding = 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')

# %%
soup.select('.title')[0].text
# Out:
# '이런 영화 어때요?'

# %%
for i in soup.select('.title')[1:]:
  print(i.text.strip()) #strip() : 앞뒤 공백 제거
# Out:
# 하얼빈
# 소방관
# 뽀로로 극장판 바닷속 대모험
# 동화지만 청불입니다
# 수퍼 소닉3
# 극장판 짱구는 못말려: 우리들의 공룡일기
# 보고타: 마지막 기회의 땅
# 무파사: 라이온 킹
# 파워링크
# 오픈톡

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get('https://ridibooks.com/category/2200')

response.encoding = 'utf-8'
html = response.text

soup = BeautifulSoup(html, 'html.parser')

# %%
# soup.select('.fig-1etljec')[0]

for i in soup.select('.fig-16r7kln'):
  print(i.text.strip()) #strip() : 앞뒤 공백 제거
# Out:
# 소프트웨어 엔지니어 가이드북
# 객체에서 함수로
# 그로킹 동시성
# LLM을 활용한 실전 AI 애플리케이션 개발
# 소프트웨어 개발에 ChatGPT 사용하기
# 전문가를 위한 리액트
# 세컨드 브레인을 구축하는 제텔카스텐 & 옵시디언
# 단위 테스트의 기술
# 진짜 쓰는 실무 엑셀
# 개정판 | 그로킹 알고리즘
# 스테이블 디퓨전 실전 가이드
